# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

headers = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})

# %%
url = "http://www.agileadvice.com/rules-of-scrum/"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

df = pd.DataFrame(columns=["Section", "Principle"])

# %%
# In Chrome, go to Developer Tools and inspect the container. Right click on the HTML, Copy -> Copy full XPath
# Beautiful Soup does not support xpath

# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-next-siblings-and-find-next-sibling
section = "The Basic Scrum Process"
ul = soup.find("p", text=section).find_next_sibling("ul")

for li in ul.find_all("li"):
    new_row = {"Section" : section, "Principle" : li.h1.a.get_text()}
    df = df.append(new_row, ignore_index = True)

# %%
section = "The rules of Scrum related to the Product Backlog"
ul = soup.find("p", text=section).find_next_sibling("ul")

for li in ul.find_all("li"):
    new_row = {"Section" : section, "Principle" : li.h1.a.get_text()}
    df = df.append(new_row, ignore_index = True)

# %%
section = "The rules of Scrum related to the Team Member Role"
ul = soup.find("p", text=section).find_next_sibling("ul")

for li in ul.find_all("li"):
    new_row = {"Section" : section, "Principle" : li.h1.a.get_text()}
    df = df.append(new_row, ignore_index = True)

# %%
section = "Rules of Scrum related to the ScrumMaster role"
ul = soup.find("p", text=section).find_next_sibling("ul")

for li in ul.find_all("li"):
    new_row = {"Section" : section, "Principle" : li.h1.a.get_text()}
    df = df.append(new_row, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c60b8e2d2f0e> in <module>
#       1 section = "Rules of Scrum related to the ScrumMaster role"
# ----> 2 ul = soup.find("p", text=section).find_next_sibling("ul")
#       3
#       4 for li in ul.find_all("li"):
#       5     new_row = {"Section" : section, "Principle" : li.h1.a.get_text()}
#
# AttributeError: 'NoneType' object has no attribute 'find_next_sibling'

# %%
section = "Rules of Scrum related to the Product Owner role"
ul = soup.find("p", text=section).find_next_sibling("ul")

for li in ul.find_all("li"):
    new_row = {"Section" : section, "Principle" : li.h1.a.get_text()}
    df = df.append(new_row, ignore_index = True)

# %%
df
# Out:
#                                              Section  \
# 0                            The Basic Scrum Process
# 1                            The Basic Scrum Process
# 2                            The Basic Scrum Process
# 3                            The Basic Scrum Process
# 4                            The Basic Scrum Process
# ..                                               ...
# 62  Rules of Scrum related to the Product Owner role
# 63  Rules of Scrum related to the Product Owner role
# 64  Rules of Scrum related to the Product Owner role
# 65  Rules of Scrum related to the Product Owner role
# 66  Rules of Scrum related to the Product Owner role
#
#                                             Principle
# 0                     Every Sprint is the Same Length
# 1      Every Sprint is Four Weeks or Less in Duration
# 2                 There are no Breaks Between Sprints
# 3   The Intention of Every Sprint is “Potentially ...
# ...

# %%
df.to_csv (r'rules_of_scrum_2020.csv'
  , index = True
  , header=True
)
